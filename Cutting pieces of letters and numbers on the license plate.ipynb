# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread('0_13-V-551-29.png')
img1 = cv.imread('0_18-SIN-744-87.png')
img2 = cv.imread('0_27-SAD-224-11.png')
img3 = cv.imread('0_42-M-958-23.png')

# %%
fig , ax = plt.subplots(4, figsize=(12,8))
ax[0].imshow(img[...,::-1])
ax[1].imshow(img1[...,::-1])
ax[2].imshow(img2[...,::-1])
ax[3].imshow(img3[...,::-1])

# %%
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
img_gray1 = cv.cvtColor(img1, cv.COLOR_BGR2GRAY)
img_gray2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)
img_gray3 = cv.cvtColor(img3, cv.COLOR_BGR2GRAY)

# %%
fig , ax = plt.subplots(4, figsize=(12,8))
ax[0].imshow(img_gray, cmap='gray')
ax[1].imshow(img_gray1, cmap='gray')
ax[2].imshow(img_gray2, cmap='gray')
ax[3].imshow(img_gray3, cmap='gray')

# %%
h, w = img_gray.shape

# %%
chopfactors = [(60,125), (125,190), (180,280), (280,350), (350,410), (410,470), (470,535), (535,600)]

# %%
fig , ax = plt.subplots(1,8, figsize=(12,8))
plate_letters = []
c = 0
for factor in chopfactors:
    w1 = int((factor[0]/600)*w)
    w2 = int((factor[1]/600)*w)
    letterpatch = img_gray[:,w1:w2]
    letterpatch_resized  = cv.resize(letterpatch, (28,28), interpolation = cv.INTER_LINEAR)
    ax[c].imshow(letterpatch_resized, cmap='gray')
    c += 1
    plate_letters.append(letterpatch_resized)

# %%
fig , ax = plt.subplots(1,8, figsize=(12,8))
plate_letters = []
c = 0
for factor in chopfactors:
    w1 = int((factor[0]/600)*w)
    w2 = int((factor[1]/600)*w)
    letterpatch = img_gray1[:,w1:w2]
    letterpatch_resized  = cv.resize(letterpatch, (28,28), interpolation = cv.INTER_LINEAR)
    ax[c].imshow(letterpatch_resized, cmap='gray')
    c += 1
    plate_letters.append(letterpatch_resized)

# %%
fig , ax = plt.subplots(1,8, figsize=(12,8))
plate_letters = []
c = 0
for factor in chopfactors:
    w1 = int((factor[0]/600)*w)
    w2 = int((factor[1]/600)*w)
    letterpatch = img_gray2[:,w1:w2]
    letterpatch_resized  = cv.resize(letterpatch, (28,28), interpolation = cv.INTER_LINEAR)
    ax[c].imshow(letterpatch_resized, cmap='gray')
    c += 1
    plate_letters.append(letterpatch_resized)

# %%
fig , ax = plt.subplots(1,8, figsize=(12,8))
plate_letters = []
c = 0
for factor in chopfactors:
    w1 = int((factor[0]/600)*w)
    w2 = int((factor[1]/600)*w)
    letterpatch = img_gray3[:,w1:w2]
    letterpatch_resized  = cv.resize(letterpatch, (28,28), interpolation = cv.INTER_LINEAR)
    ax[c].imshow(letterpatch_resized, cmap='gray')
    c += 1
    plate_letters.append(letterpatch_resized)
